# %%
with open('esperanto_data/english_low.txt') as engl, open('esperanto_data/esperanto_low.txt') as esp:
    for en, es in zip(engl, esp):
        print("ENG {0}\t ESP{1}END".format(en.strip(), es.strip()))
# Out:
# ENG from students' essays	 ESPel eseoj de studentojEND
# ENG his thoughts tumbled in his head, making and breaking alliances like underpants in a washing machine.	 ESPliaj pensoj kunfalis en la kapo, farante kaj rompante aliancojn kiel kalsono en lavmaŝinoEND
# ENG the little boat slowly drifted across the pond in exactly the same way a bowling ball wouldn't.	 ESPla malgranda boato malrapide drivis trans la lageto, samkiel keglopilko ne drivus.END
# ENG john and mary had never met. they were like two humming-birds who had also never met.	 ESPjohano kaj maria neniam jam renkontiĝis.  ili similis al du kolibroj, kiuj ankaŭ neniam jam renkontiĝis.END
# ENG she had a deep, throaty laugh, like the sound a dog makes just before it throws up.	 ESPŝi havis malaltan, ĝorĝan ridon, kiel tiu sono kiun faras hundo ĵus antaŭ ol ĝi vomas.END
# ENG the red brick wall was the color of a brick-red crayon.	 ESPla ruĝa brika muro havis la koloron de brik-ruĝa paŝtelo.END
# ...
